# %%
## Install Pandas Data Reader
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_tesla = pd.read_csv('/content/drive/MyDrive/dataset/TSLA.csv')

# %%
df_tesla.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df_tesla.tail()
# Out:
#             Date         Open         High         Low        Close  \
# 2951  2022-03-18   874.489990   907.849976  867.390015   905.390015
# 2952  2022-03-21   914.979980   942.849976  907.090027   921.159973
# 2953  2022-03-22   930.000000   997.859985  921.750000   993.979980
# 2954  2022-03-23   979.940002  1040.699951  976.400024   999.109985
# 2955  2022-03-24  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume
# 2951   905.390015  33408500
# 2952   921.159973  27327200
# 2953   993.979980  35289500
# 2954   999.109985  40225400
# 2955  1013.919983  22901900

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: >

# %%
df_tesla['Date'] = pd.to_datetime(df_tesla['Date'])
df_tesla.set_index('Date', inplace=True)

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2956 entries, 0 to 2955
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2956 non-null   datetime64[ns]
#  1   Open       2956 non-null   float64
#  2   High       2956 non-null   float64
#  3   Low        2956 non-null   float64
#  4   Close      2956 non-null   float64
#  5   Adj Close  2956 non-null   float64
#  6   Volume     2956 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 161.8 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla
# Out:
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2010-06-29     3.800000     5.000000    3.508000     4.778000     4.778000
# 2010-06-30     5.158000     6.084000    4.660000     4.766000     4.766000
# 2010-07-01     5.000000     5.184000    4.054000     4.392000     4.392000
# 2010-07-02     4.600000     4.620000    3.742000     3.840000     3.840000
# 2010-07-06     4.000000     4.000000    3.166000     3.222000     3.222000
# ...                 ...          ...         ...          ...          ...
# 2022-03-18   874.489990   907.849976  867.390015   905.390015   905.390015
# 2022-03-21   914.979980   942.849976  907.090027   921.159973   921.159973
# 2022-03-22   930.000000   997.859985  921.750000   993.979980   993.979980
# 2022-03-23   979.940002  1040.699951  976.400024   999.109985   999.109985
# 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983  1013.919983
#
#               Volume
# Date
# 2010-06-29  93831500
# ...

# %%
A = df_tesla['High'].rolling(2).mean()

# %%
A
# Out:
# Date
# 2010-06-29            NaN
# 2010-06-30       5.542000
# 2010-07-01       5.634000
# 2010-07-02       4.902000
# 2010-07-06       4.310000
#                  ...
# 2022-03-18     891.424988
# 2022-03-21     925.349976
# 2022-03-22     970.354981
# 2022-03-23    1019.279968
# 2022-03-24    1032.594971
# Name: High, Length: 2956, dtype: float64

# %%
A = df_tesla['High'].rolling(100).mean().plot(figsize=(15,6))
